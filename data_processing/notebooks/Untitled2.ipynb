# %%
# Notebook phân tích & xây dựng mapping cho dữ liệu bất động sản
import os
import sys
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import (
    col, to_timestamp, current_timestamp, lit, regexp_replace, trim,
    when, upper, lower, split, element_at, round as spark_round,
    avg, count, percentile_approx, stddev, min as spark_min, max as spark_max,
    udf, length, expr
)
from pyspark.sql.types import StringType, DoubleType, BooleanType
from pyspark.sql.window import Window

# Thêm thư mục gốc vào sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

# Tạo Spark Session
spark = SparkSession.builder \
    .appName("BatDongSan Mapping Analysis") \
    .config("spark.ui.port", "4050") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:9000") \
    .getOrCreate()

print("Spark session created successfully")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/25 07:51:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/25 07:51:24 WARN Utils: Service 'SparkUI' could not bind on port 4050. Attempting port 4051.
# Spark session created successfully

# %%
parquet_file = "/data/realestate/processed/gold/unified/house/2025/05/24/unified_house_20250524.parquet"
df = spark.read.parquet(parquet_file)

# Xem thử dữ liệu
df.show(5, truncate=False)
# Out:
# 25/05/25 07:51:42 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +--------------------------------+------------------------------------+------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+---------+--------------+--------------+------------------+---------+----------+------+-----+------------+-------+--------+-----------+---------------+------------+--------+----------+------+------+-----------+------------+----------+-------------------+-------------------+------------------+--------------------------+-----------------------------+-------------+
# |id                              |url                                 |source|title                                                                 |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |location                                                     |data_type|province      |district      |ward              |latitude |longitude |price |area |price_per_m2|bedroom|bathroom|floor_count|house_direction|legal_status|interior|house_type|width |length|living_size|facade_width|road_width|posted_date        |crawl_timestamp    |data_quality_score|processing_timestamp      |processing_id                |property_type|
# +--------------------------------+------------------------------------+------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+---------+--------------+--------------+------------------+---------+----------+------+-----+------------+-------+--------+-----------+---------------+------------+--------+----------+------+------+-----------+------------+----------+-------------------+-------------------+------------------+--------------------------+-----------------------------+-------------+
# |a71bf43c9b0643879f507d67c3ef4506|https://nha.chotot.com/124825595.htm|chotot|Nhà 4 tầng vào ở ngay, hẻm rộng 1 Xẹt gần đường Hưng Phú Quận 8       |Bán nhà hẻm Hưng Phú Quận 8. Nhà hẻm 1 xẹt, góc 2 mặt hẻm, gần THCS Lý Thánh Tông – Diện tích đất: 16m2 (3.3m x 6m); Diện tích sử dụng: 60m2 – Hiện trạng: 1 trệt 2 lầu sân thượng với 2 phòng ngủ, 3WC – Hướng: Đông Nam – Pháp lý: Sổ hồng riêng, công chứng sang tên ngay – Vị trí: căn góc 2 mặt hẻm xe máy, cách mặt tiền đường 75m – Tiện ích: Chợ/TTTM: chợ Hưng Phú cách 700m, chợ Ba Đình cách 850m Trường học: Tiểu học Hưng Phú cách 1km, Tiểu học Lý Nhân Tông cách 600m, THCS Lý Thánh Tông cách 300m -------------------------------------- Liên hệ: *** Minh 𝐶ℎ𝑢𝑦𝑒̂𝑛 𝑑𝑖̣𝑐ℎ 𝑣𝑢̣: ✔️ 𝑁ℎ𝑎̣̂𝑛 𝑘𝑦́ 𝑔𝑢̛̉𝑖 - 𝑀𝑢𝑎 𝑏𝑎́𝑛 𝑛ℎ𝑎̀ đ𝑎̂́𝑡 ✔️𝑋𝑒𝑚 𝑞𝑢𝑦 ℎ𝑜𝑎̣𝑐ℎ, 𝑡𝑟𝑎𝑛ℎ 𝑐ℎ𝑎̂́𝑝 ✔️ Đ𝑎̆𝑛𝑔 𝑏𝑜̣̂ 𝑠𝑎𝑛𝑔 𝑡𝑒̂𝑛 ✔️ 𝐻𝑜̛̣𝑝 𝑡ℎ𝑢̛́𝑐 ℎ𝑜́𝑎 𝑛ℎ𝑎̀ đ𝑎̂́�
# |cd1ba8cbc8aa9ed5f81ffb338132aff7|https://nha.chotot.com/116219582.htm|chotot|Bán Nhà Phan Huy Ích, 5,5m x 13m, 5 Tầng HXH nhỉnh 5 Tỷ               |Nhà 1/ Phan Huy Ích, p12, Gò Vấp - Cạnh Emart 2 Phan Huy Ích, Hẻm ô tô sạch đẹp - gồm 5 Tầng, hiện đang cho thuê 22 triệu/ tháng - Phù hợp gia đình đông thành viên hoặc làm căn hộ dich vụ - Diện tích 5,5m x 13m Giá Nhỉnh 5 tỷ 2 Liên hệ em Trang để xem nhà và xem sổ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |Đường Phan Huy Ích, Phường 12, Quận Gò Vấp, Tp Hồ Chí Minh   |house    |Tp Hồ Chí Minh|Quận Gò Vấp   |Phường 12         |10.8373  |106.6362  |5.3E10|71.0 |7.464789E7  |7.0    |1.0     |5.0        |               |1           |1       |3         |5.5   |13.0  |200.0      |null        |null      |2025-05-24 07:17:58|2025-05-24 16:21:43|100               |2025-05-25 07:39:02.346616|property_unify_20250525073903|3            |
# +--------------------------------+------------------------------------+------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+---------+--------------+--------------+------------------+---------+----------+------+-----+------------+-------+--------+-----------+---------------+------------+--------+----------+------+------+-----------+------------+----------+-------------------+-------------------+------------------+--------------------------+-----------------------------+-------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType, DateType

# Chuyển cột dạng Date và Timestamp sang String
for name, dtype in df.dtypes:
    if dtype in ('timestamp', 'date'):
        df = df.withColumn(name, col(name).cast("string"))

df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- data_type: string (nullable = true)
#  |-- province: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- price: double (nullable = true)
#  |-- area: double (nullable = true)
#  |-- price_per_m2: double (nullable = true)
#  |-- bedroom: double (nullable = true)
#  |-- bathroom: double (nullable = true)
#  |-- floor_count: double (nullable = true)
#  |-- house_direction: string (nullable = true)
#  |-- legal_status: string (nullable = true)
#  |-- interior: string (nullable = true)
#  |-- house_type: string (nullable = true)
#  |-- width: double (nullable = true)
#  |-- length: double (nullable = true)
#  |-- living_size: double (nullable = true)
#  |-- facade_width: double (nullable = true)
#  |-- road_width: double (nullable = true)
#  |-- posted_date: string (nullable = true)
#  |-- crawl_timestamp: string (nullable = true)
#  |-- data_quality_score: integer (nullable = true)
#  |-- processing_timestamp: string (nullable = true)
#  |-- processing_id: string (nullable = true)
#  |-- property_type: string (nullable = true)

# %%
import os

output_dir = "/tmp/house_data_csv"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

csv_output_path = f"{output_dir}/house_data.csv"

# Lưu DataFrame dưới dạng file CSV
df.toPandas().to_csv(csv_output_path, index=False)

# Kiểm tra file
print(f"File CSV đã được lưu tại: {csv_output_path}")
print(f"Kích thước file: {os.path.getsize(csv_output_path) / (1024*1024):.2f} MB")
# Out:
# File CSV đã được lưu tại: /tmp/house_data_csv/house_data.csv
# Kích thước file: 2.08 MB

# %%
from IPython.display import HTML
import base64

def create_download_link(file_path, filename=None):
    if filename is None:
        filename = os.path.basename(file_path)

    with open(file_path, "rb") as f:
        data = f.read()

    b64 = base64.b64encode(data).decode()
    href = f'<a download="{filename}" href="data:text/csv;base64,{b64}" target="_blank">Tải xuống {filename}</a>'
    return HTML(href)

# Hiển thị link tải xuống
create_download_link(csv_output_path, "house_data.csv")
# Out:
# <a download="house_data.csv" href="data:text/csv;base64,..." target="_blank">Tải xuống house_data.csv</a>
